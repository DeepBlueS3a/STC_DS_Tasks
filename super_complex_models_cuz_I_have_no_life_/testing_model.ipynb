# %% [markdown]
# Just to check whether the saved model works, and compiles properly

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
tomato_disease = keras.models.load_model("cnn_model")
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
tomato_disease.build()

# %%
keras.utils.plot_model(tomato_disease)
